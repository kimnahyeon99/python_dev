# %% [markdown]
# pip install beautifulsoup4

# %%
# BeautifulSoup lib 사용법
# import
from bs4 import BeautifulSoup # class import

page = open('./data/03. test_first.html', 'r').read() # file object 생성
# page = page.read() # 전체 읽어서 문자열로 반환
# 위처럼 쓸 수 있는 걸
# .read() 이렇게 사용가능

# print(page) # 문자열일뿐이다
# Dom tree 생성되고 selector 가능해진다
soup = BeautifulSoup(page,'html.parser')

# %%
# 데이터 추출시 자주 사용하는 메소드
# 1. find() : 주어진 태그와 속성을 가진 첫번째 요소를 검색할 때 사용
# 2. find_all() : 주어진 태그와 속성을 가진 모든 요소를 검색할 때 사용
# 3. select_one() : CSS Selector 사용해서 첫번째 요소를 검색할 때 사용
# 4. select() : CSS Selector 사용해서 모든 요소를 검색할 때 사용 // 많이씀

# %%
html = list(soup.children)[2]
html
# Out:
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
body = list(html.children)[3]
list(body.children)
# Out:
# ['\n',
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>,
#  '\n',
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  '\n',
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>,
#  '\n']

# %%
# p tag 전체 검색
soup.find_all('p') # 검색 결과 여러개를 리스트로 반환
# soup.find('p') # 첫번째 검색 결과 반환
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>,
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>,
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
# p tag, class='outer-text' 검색
soup.find_all('p', class_='outer-text')
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all('p',id='first')
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>]

# %%
soup.find_all('p')[0].get_text() # 문자열 추출
# Out:
# '\n                Happy PinkWink.\n                PinkWink\n'

# %%
links = soup.find_all('a')
link = links[0]
link['href'] # 링크에서 href 속성의 값 추출
# Out:
# 'http://www.pinkwink.kr'

# %%
for link in links:
    href = link['href']
    print(href)
# Out:
# http://www.pinkwink.kr
# https://www.python.org

# %%
# 네이버 증권 사이트에서 환율 정보
from urllib.request import urlopen

url = 'https://finance.naver.com/marketindex/'
page=urlopen(url)

soup=BeautifulSoup(page,'html.parser')
# soup.find_all('span',class_='value')[0].get_text()
soup.find_all('span',class_='value')[0].string
# Out:
# '1,456.70'

# %% [markdown]
# ---
# #### 시카고 샌드위치 맛집 사이트 분석
# ---

# %%
# import
import numpy as np
import pandas as pd

from bs4 import BeautifulSoup
from urllib.request import urlopen # 에러가 발생해서 
# 밑에 requests 모듈로 바꿈

# %%
# https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago
import requests

headers={
    'User-Agent':'Mozilla/5.0'
}

url_base='https://www.chicagomag.com'
# 현재는 샌드위치 메인 페이지 URL
url_sub='/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago'

# main page
url = url_base + url_sub

html = requests.get(
    url=url
    , headers=headers
).text # html을 text로 변경

# print(html)

# %%
# DOM Tree 생성 => html, Selector 사용해서 검색 => 데이터 추출
soup = BeautifulSoup(html,'html.parser')

# %%
# 태그 : p / class : sammy element 검색
# find all : 모두 찾아라 => 리스트 (50개)
# soup.find_all('div', class_='sammy')

# %%
# 1개만 가져와서 우리가 원하는 데이터 추출
tmp = soup.find_all('div', class_='sammy')[0]
tmp
# Out:
# <div class="sammy" style="position: relative;">
# <div class="sammyRank">1</div>
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>
# </div>

# %%
# Rank 추출
tmp.find(class_='sammyRank').text
# Out:
# '1'

# %%
tmp.find(class_='sammyListing')
# Out:
# <div class="sammyListing"><a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a></div>

# %%
tmp.find(class_='sammyListing').text
# Out:
# 'BLT\nOld Oak Tap\nRead more '

# %%
tmp.find(class_='sammyListing').text.split('\n')
# Out:
# ['BLT', 'Old Oak Tap', 'Read more ']

# %%
k = tmp.find(class_='sammyListing').text.split('\n')
k
# Out:
# ['BLT', 'Old Oak Tap', 'Read more ']

# %%
k[0], k[1]
# Out:
# ('BLT', 'Old Oak Tap')

# %%
# a href 추출
tmp.find('a')
# Out:
# <a href="/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/"><b>BLT</b><br/>
# Old Oak Tap<br/>
# <em>Read more</em> </a>

# %%
tmp.find('a')['href']
# Out:
# '/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
# 샌드위치 메인 페이지 데이터 추출
import requests

# 메인 페이지 URL 
url_base = 'https://www.chicagomag.com'
url_sub = '/Chicago-Magazine/November-2012/Best-Sandwiches-Chicago'

url = url_base + url_sub

#header
headers={
    'User-Agent' : 'Mozilla/5.0'
} 

response = requests.get(
    url = url
    , headers=headers
).text

# 파싱
soup = BeautifulSoup(response,'html.parser')

# 데이터 추출
# 1) 순위, 2) 메인메뉴, 3) 카페명, 4) url필요(세부페이지 이동 url)
ranks = []
main_memus =[]
cafe_names = []
url_address=[]  # 상세로 들어가는 URL 

# 50개 정보가 들어 있는 리스트 
list_soup = soup.find_all('div',class_='sammy')

# 반복 처리해서 데이터를 추출하고 각 리스트에 저장
for item in list_soup: #50번 반복 
    # 순위 추출 해서 저장
    ranks.append(item.find(class_='sammyRank').text)
    # 메인메뉴와 카페명 추출해서 저장 -> 문자열로 나옴 
    tmp_str=item.find(class_='sammyListing').text
    main_memus.append(tmp_str.split('\n')[0]) # BLT
    cafe_names.append(tmp_str.split('\n')[1])  # Ola Oak Tap
    
    tmp_url = item.find('a')['href'] # sub의 URL 추출 
    # https://로 시작하거나 /Chicago로 시작할 수 있다.
    if tmp_url.startswith('https://'):
        url_address.append(tmp_url)
    else: #https://로 시작하지 않으면
        url_address.append(url_base + tmp_url)

# %%
# 데이터 수집 확인
print(ranks[:5])
print(main_memus[:5])
print(cafe_names[:5])
print(url_address[:5])
# Out:
# ['1', '2', '3', '4', '5']
# ['BLT', 'Fried Bologna', 'Woodland Mushroom', 'Roast Beef', 'PB&L']
# ['Old Oak Tap', 'Au Cheval', 'Xoco', 'Al’s Deli', 'Publican Quality Meats']
# ['https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/', 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/', 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/', 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Als-Deli-Roast-Beef/', 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Publican-Quality-Meats-PB-L/']

# %%
url_address
# Out:
# ['https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Au-Cheval-Fried-Bologna/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Xoco-Woodland-Mushroom/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Als-Deli-Roast-Beef/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Publican-Quality-Meats-PB-L/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Hendrickx-Belgian-Bread-Crafter-Belgian-Chicken-Curry-Salad/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Acadia-Lobster-Roll/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Birchwood-Kitchen-Smoked-Salmon-Salad/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Cemitas-Puebla-Atomica-Cemitas/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Nana-Grilled-Laughing-Bird-Shrimp-and-Fried-Oyster-Po-Boy/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Lula-Cafe-Ham-and-Raclette-Panino/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Ricobenes-Breaded-Steak/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Frog-n-Snail-The-Hawkeye/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Crosbys-Kitchen-Chicken-Dip/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Longman-and-Eagle-Wild-Boar-Sloppy-Joe/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Bari-Meatball-Sub/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Mannys-Corned-Beef/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Eggys-Turkey-Club/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Jerusalem-Falafel/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Mindys-HotChocolate-Crab-Cake/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Olgas-Delicatessen-Chicken-Schnitzel/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Dawali-Mediterranean-Kitchen-Shawarma/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Big-Jones-Toasted-Pimiento-Cheese/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-La-Pane-Vegetarian-Panino/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Pastoral-Cali-Chevre/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Maxs-Deli-Pastrami/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Luckys-Sandwich-Co-The-Fredo/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-City-Provisions-Smoked-Ham/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Papas-Cache-Sabroso-Jibarito/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Bavettes-Bar-and-Boeuf-Shaved-Prime-Rib/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Hannahs-Bretzel-Serrano-Ham-and-Manchego-Cheese/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-La-Fournette-Tuna-Salad/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Paramount-Room-Paramount-Reuben/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Melt-Sandwich-Shoppe-The-Istanbul/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Floriole-Cafe-and-Bakery-BAD/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-First-Slice-Pie-Cafe-Duck-Confit-and-Mozzarella/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Troquet-Croque-Monsieur/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Grahamwich-Green-Garbanzo/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Saigon-Sisters-The-Hen-House/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Rosalias-Deli-Tuscan-Chicken/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Z-and-H-MarketCafe-The-Marty/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Market-House-on-the-Square-Whitefish/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Elaines-Coffee-Call-Oat-Bread-Pecan-Butter-and-Fruit-Jam/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Marion-Street-Cheese-Market-Cauliflower-Melt/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Cafecito-Cubano/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Chickpea-Kufta/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-The-Goddess-and-Grocer-Debbies-Egg-Salad/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Zenwich-Beef-Curry/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Toni-Patisserie-Le-Vegetarien/',
#  'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Phoebes-Bakery-The-Gatsby/']

# %%
# DataFrame 생성
data_df=pd.DataFrame({
    'Rank':ranks,
    'Menu':main_memus,
    'Cafe':cafe_names,
    'Url':url_address
})
data_df.head()
# Out:
#   Rank               Menu                    Cafe  \
# 0    1                BLT             Old Oak Tap
# 1    2      Fried Bologna               Au Cheval
# 2    3  Woodland Mushroom                    Xoco
# 3    4         Roast Beef               Al’s Deli
# 4    5               PB&L  Publican Quality Meats
#
#                                                  Url
# 0  https://www.chicagomag.com/Chicago-Magazine/No...
# 1  https://www.chicagomag.com/Chicago-Magazine/No...
# 2  https://www.chicagomag.com/Chicago-Magazine/No...
# 3  https://www.chicagomag.com/Chicago-Magazine/No...
# 4  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
# data_df 파일을 저장
data_df.to_csv(
    './data/03. 시카고 샌드위치 메인 페이지 데이터.csv'
    , encoding='utf-8'
)

# %%
# 서브 페이지 이동해서 가격, 주소 추출
# 1등 서브페이지로 이동해서 가격, 주소
url_str=data_df['Url'][0]
url_str
# Out:
# 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
# 헷갈릴수도 있으니 다시 import
import requests
from bs4 import BeautifulSoup

url_str=data_df['Url'][0]

headers={
    'User-Agent':'Mozilla/5.0'
}

response=requests.get(url=url_str, headers=headers).text

# text => DOM 파싱
tmp_soup=BeautifulSoup(response, 'html.parser')

# 가격, 주소가 있는 영역 추출 <p class='addy>가격, 주소</p>
price_address=tmp_soup.find('p', class_='addy').text
price_address # 중간확인
# Out:
# '\n$10. 2109 W. Chicago Ave., 773-772-0406, theoldoaktap.com'

# %%
price_address.split() # 공백으로 분리 => 리스트로 반환된다.
# Out:
# ['$10.', '2109', 'W.', 'Chicago', 'Ave.,', '773-772-0406,', 'theoldoaktap.com']

# %%
# 가격 추출
price_address.split()[0][:-1]
# Out:
# '$10'

# %%
# 주소 추출
# 주소 = 가변길이
# ['$10.', '2109', 'W.', 'Chicago', 'Ave.,', '773-772-0406,', 'theoldoaktap.com']
price_address.split()[1:-2]
# [1:-2] : 뒤에서 두개빼는 것
# Out:
# ['2109', 'W.', 'Chicago', 'Ave.,']

# %%
# ['2109', 'W.', 'Chicago', 'Ave.,'] 리스트의 값들을
# 하나의 문자열로 연결하는 함수 : join()
' '.join(price_address.split()[1:-2])
# Out:
# '2109 W. Chicago Ave.,'

# %% [markdown]
# pip install tqdm

# %%
# url이 50개다. 50번 반복 처리
# 반복시 반복 상태를 화면에 표시 : tqdm // for문에 사용해야한다.

from tqdm import tqdm

# 가격, 주소 저장
price=[]
address=[]

# tqdm은 for 반복문에 사용되어야 한다
for idx in tqdm(data_df['Url'].index): # [0 ~ 49] index를 가지고 있는 리스트
    url=data_df['Url'][idx] # url 한개씩 추출
    
    headers={
        'User-Agent':'Mozilla/5.0'
    }    
    response=requests.get(url=url, headers=headers).text
    soup=BeautifulSoup(response, 'html.parser')
    get_str=soup.find('p', class_='addy').text
    price.append(get_str.split()[0][:-1])
    address.append(' '.join(get_str.split()[1:-2]))
# Out:
# 100%|██████████| 50/50 [00:53<00:00,  1.07s/it]

# %%
# 데이터 잘 가져왔는지 확인
price[:5], address[:5]
# Out:
# (['$10', '$9', '$9.50', '$9.40', '$10'],
#  ['2109 W. Chicago Ave.,',
#   '800 W. Randolph St.,',
#   '445 N. Clark St.,',
#   '914 Noyes St., Evanston,',
#   '825 W. Fulton Mkt.,'])

# %%
# data_df DataFrame 위 데이터 추가
data_df['Price']=price
data_df['Address']=address

data_df.head()
# Out:
#   Rank               Menu                    Cafe  \
# 0    1                BLT             Old Oak Tap
# 1    2      Fried Bologna               Au Cheval
# 2    3  Woodland Mushroom                    Xoco
# 3    4         Roast Beef               Al’s Deli
# 4    5               PB&L  Publican Quality Meats
#
#                                                  Url  Price  \
# 0  https://www.chicagomag.com/Chicago-Magazine/No...    $10
# 1  https://www.chicagomag.com/Chicago-Magazine/No...     $9
# 2  https://www.chicagomag.com/Chicago-Magazine/No...  $9.50
# 3  https://www.chicagomag.com/Chicago-Magazine/No...  $9.40
# 4  https://www.chicagomag.com/Chicago-Magazine/No...    $10
#
#                     Address
# 0     2109 W. Chicago Ave.,
# 1      800 W. Randolph St.,
# 2         445 N. Clark St.,
# 3  914 Noyes St., Evanston,
# 4       825 W. Fulton Mkt.,

# %%
# Rank      Menu    Cafe    Price   Address
# del data_df
data_result_df = data_df[['Rank','Menu','Cafe','Price','Address']] # 팬시색인 : 원하는 컬럼만 선택할 수 있다.
data_result_df.head()
# Out:
#   Rank               Menu                    Cafe  Price  \
# 0    1                BLT             Old Oak Tap    $10
# 1    2      Fried Bologna               Au Cheval     $9
# 2    3  Woodland Mushroom                    Xoco  $9.50
# 3    4         Roast Beef               Al’s Deli  $9.40
# 4    5               PB&L  Publican Quality Meats    $10
#
#                     Address
# 0     2109 W. Chicago Ave.,
# 1      800 W. Randolph St.,
# 2         445 N. Clark St.,
# 3  914 Noyes St., Evanston,
# 4       825 W. Fulton Mkt.,

# %%
data_result_df.set_index(
    'Rank' # 인덱스로 보낼 컬럼들 지정
    , inplace=True
)

# %%
# 파일에 저장
data_result_df.to_csv(
    './data/03. best_sandwiches_list_chicago2.csv'
    , encoding='utf-8'
)

# %%
import numpy as np
import pandas as pd
import folium
import googlemaps

# %%
# 한개 주소만 가져와서 위도, 경도 추출 확인
# 한개 주소
# data_result_df['Address'][0] => 경고가 뜬다.
# loc[행,열] : named index 사용
# iloc[행,열] : integer index 사용
# data_result_df.head()
# data_result_df.loc['1','Address'] => '2109 W. Chicago Ave.,'
gmaps_key='AIzaSyCRxIgstOs32GDCO9t3CzdfaLAnb5tu0fI'

# Client 생성
gmaps=googlemaps.Client(key=gmaps_key)
target_name=data_result_df.loc['1','Address'] + 'Chicago' # 시카고가 포함된 주소
gmaps_output=gmaps.geocode(target_name)[0].get('geometry')
print(gmaps_output['location']['lat'])
print(gmaps_output['location']['lng'])
# Out:
# 41.8955886
# -87.6799623

# %%
# lat, lng 구한다.
# data_result_df['Address'] : 데이터를 먼저 확인
# 주소에 multiple = 주소가 없다.
lat=[]
lng=[]

for idx in tqdm(data_result_df.index): # 50번 반복
    if data_result_df['Address'][idx] != 'Multiple':
        # 주소가 있는 경우 => 구글로 보내서 lat, lng 구한다
        target_name = data_result_df.loc[idx, 'Address'] + 'Chicago'
        gmaps_output=gmaps.geocode(target_name) # 주소가 들어있는 리스트 반환
        location_output=gmaps_output[0].get('geometry') # 딕셔너리 반환
        lat.append(location_output['location']['lat'])
        lng.append(location_output['location']['lng'])
    else:
        # 주소가 없는 경우 : lat, lng => NaN처리
        lat.append(np.nan)
        lng.append(np.nan)
# Out:
# 100%|██████████| 50/50 [00:07<00:00,  6.54it/s]

# %%
# 데이터 확인
len(lat), len(lng)
# Out:
# (50, 50)

# %%
data_result_df['Lat']=lat
data_result_df['Lng']=lng
data_result_df
# Out:
# /var/folders/lm/7_ldljsn2wv8dzrqnlx17vrh0000gn/T/ipykernel_25428/4255682238.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_result_df['Lat']=lat
#                                                 Menu  \
# Rank
# 1                                                BLT
# 2                                      Fried Bologna
# 3                                  Woodland Mushroom
# 4                                         Roast Beef
# 5                                               PB&L
# 6                        Belgian Chicken Curry Salad
# 7                                       Lobster Roll
# 8                                Smoked Salmon Salad
# 9                                    Atomica Cemitas
# 10    Grilled Laughing Bird Shrimp and Fried Po’ Boy
# 11                           Ham and Raclette Panino
# 12                                     Breaded Steak
# 13                                       The Hawkeye
# 14                                       Chicken Dip
# 15                              Wild Boar Sloppy Joe
# 16                                      Meatball Sub
# 17                                       Corned Beef
# 18                                       Turkey Club
# 19                                           Falafel
# 20                                         Crab Cake
# 21                                 Chicken Schnitzel
# 22                                          Shawarma
# 23                           Toasted Pimiento Cheese
# 24                                 Vegetarian Panino
# 25                                       Cali Chèvre
# 26                                          Pastrami
# 27                                         The Fredo
# 28                                        Smoked Ham
# 29                                          Jibarito
# 30                                  Shaved Prime Rib
# 31                   Serrano Ham and Manchego Cheese
# 32                                        Tuna Salad
# 33                                  Paramount Reuben
# 34                                      The Istanbul
# 35                                            B.A.D.
# 36                        Duck Confit and Mozzarella
# 37                                   Croque Monsieur
# 38                                    Green Garbanzo
# 39                                     The Hen House
# 40                                    Tuscan Chicken
# 41                                        The Marty
# 42                                         Whitefish
# 43            Oat Bread, Pecan Butter, and Fruit Jam
# 44                                  Cauliflower Melt
# 45                                            Cubana
# 46                                             Kufta
# 47                                Debbie’s Egg Salad
# 48                                        Beef Curry
# 49                                     Le Végétarien
# 50                                        The Gatsby
#
#                                  Cafe   Price  \
# Rank
# 1                         Old Oak Tap     $10
# 2                           Au Cheval      $9
# 3                                Xoco   $9.50
# 4                           Al’s Deli   $9.40
# 5              Publican Quality Meats     $10
# 6     Hendrickx Belgian Bread Crafter   $7.25
# 7                              Acadia     $16
# 8                   Birchwood Kitchen     $10
# 9                      Cemitas Puebla      $9
# 10                               Nana     $17
# 11                          Lula Cafe     $11
# 12                         Ricobene’s   $5.49
# 13                       Frog n Snail     $14
# 14                   Crosby’s Kitchen     $10
# 15                    Longman & Eagle     $13
# 16                               Bari   $4.50
# 17                            Manny’s  $11.95
# 18                             Eggy’s  $11.50
# 19                      Old Jerusalem   $6.25
# 20               Mindy’s HotChocolate     $15
# 21                Olga’s Delicatessen      $5
# 22       Dawali Mediterranean Kitchen      $6
# 23                          Big Jones      $8
# 24                            La Pane   $5.99
# 25                           Pastoral   $7.52
# 26                         Max’s Deli  $11.95
# 27               Lucky’s Sandwich Co.   $7.50
# 28                    City Provisions  $12.95
# 29               Papa’s Cache Sabroso      $7
# 30              Bavette’s Bar & Boeuf     $21
# 31                   Hannah’s Bretzel   $9.79
# 32                       La Fournette   $9.75
# 33                     Paramount Room     $13
# 34               Melt Sandwich Shoppe   $7.95
# 35             Floriole Cafe & Bakery      $9
# 36               First Slice Pie Café      $9
# 37                            Troquet      $8
# 38                         Grahamwich      $8
# 39                     Saigon Sisters      $7
# 40                     Rosalia’s Deli      $6
# 41                     Z&H MarketCafe   $7.25
# 42         Market House on the Square     $11
# 43               Elaine’s Coffee Call      $6
# 44        Marion Street Cheese Market      $9
# 45                           Cafecito   $5.49
# 46                           Chickpea      $8
# 47             The Goddess and Grocer   $6.50
# 48                            Zenwich   $7.50
# 49                    Toni Patisserie   $8.75
# 50                    Phoebe’s Bakery   $6.85
#
#                                     Address        Lat        Lng
# Rank
# 1                     2109 W. Chicago Ave.,  41.895589 -87.679962
# 2                      800 W. Randolph St.,  41.884639 -87.647590
# 3                         445 N. Clark St.,  41.890523 -87.630783
# 4                  914 Noyes St., Evanston,  42.058322 -87.683748
# 5                       825 W. Fulton Mkt.,  41.886604 -87.648536
# 6                             100 E. Walton  41.900115 -87.625100
# 7                      1639 S. Wabash Ave.,  41.859057 -87.625220
# 8                       2211 W. North Ave.,  41.910203 -87.682875
# 9                       3619 W. North Ave.,  41.909758 -87.717677
# 10                     3267 S. Halsted St.,  41.834530 -87.645649
# 11                    2537 N. Kedzie Blvd.,  41.927643 -87.706826
# 12                                 Multiple        NaN        NaN
# 13                        3124 N. Broadway,  41.938455 -87.644628
# 14                  3455 N. Southport Ave.,  41.945114 -87.663697
# 15                     2657 N. Kedzie Ave.,  41.930056 -87.707034
# 16                      1120 W. Grand Ave.,  41.891311 -87.655531
# 17                   1141 S. Jefferson St.,  41.867853 -87.641929
# 18                       333 E. Benton Pl.,  41.885269 -87.618484
# 19                       1411 N. Wells St.,  41.908055 -87.634312
# 20                      1747 N. Damen Ave.,  41.913678 -87.677190
# 21                      3209 W. Irving Park  41.953833 -87.719328
# 22                                 Multiple        NaN        NaN
# 23                       5347 N. Clark St.,  41.979449 -87.667976
# 24                 2954 W. Irving Park Rd.,  41.954159 -87.702711
# 25                                 Multiple        NaN        NaN
# 26    191 Skokie Valley Rd., Highland Park,  42.156707 -87.803635
# 27                                 Multiple        NaN        NaN
# 28                     1818 W. Wilson Ave.,  41.965278 -87.675542
# 29                    2517 W. Division St.,  41.902733 -87.690218
# 30                            218 W. Kinzie  41.889368 -87.634949
# 31                                 Multiple        NaN        NaN
# 32                       1547 N. Wells St.,  41.910526 -87.634377
# 33                   415 N. Milwaukee Ave.,  41.889636 -87.644840
# 34                      1840 N. Damen Ave.,  41.915050 -87.677805
# 35                    1220 W. Webster Ave.,  41.921835 -87.659214
# 36                    5357 N. Ashland Ave.,  41.979710 -87.669344
# 37                   1834 W. Montrose Ave.,  41.961712 -87.675816
# 38                        615 N. State St.,  41.892915 -87.627826
# 39                                 Multiple        NaN        NaN
# 40               241 N. York Rd., Elmhurst,  41.904758 -87.939651
# 41                        1323 E. 57th St.,  41.791283 -87.593844
# 42            655 Forest Ave., Lake Forest,  42.251784 -87.841353
# 43        Hotel Lincoln, 1816 N. Clark St.,  41.915287 -87.634389
# 44             100 S. Marion St., Oak Park,  41.886362 -87.802230
# 45                    26 E. Congress Pkwy.,  41.875821 -87.626457
# 46                    2018 W. Chicago Ave.,  41.896113 -87.677857
# 47                      25 E. Delaware Pl.,  41.898979 -87.627393
# 48               416 N. York St., Elmhurst,  41.910583 -87.940488
# 49                    65 E. Washington St.,  41.883106 -87.625438
# 50                        3351 N. Broadway,  41.943163 -87.644507

# %%
# 지도 표시
map=folium.Map(
    location=[ # 경도 위도의 평균값을 줘서 지도 중심 설정
        data_result_df['Lat'].mean()
        , data_result_df['Lng'].mean()
    ]
    , zoom_start=11
)

# 50개 맛집 주소 마커 출력
for idx in data_result_df.index:
    if data_result_df['Address'][idx] != 'Multiple':
        folium.Marker(
            [data_result_df['Lat'][idx], data_result_df['Lng'][idx]]
            , popup=data_result_df['Cafe'][idx]
        ).add_to(map)
        
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7b75dc57570724e91fef5d27e2db884c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7b75dc57570724e91fef5d27e2db884c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7b75dc57570724e91fef5d27e2db884c = L.map(
#                 &quot;map_7b75dc57570724e91fef5d27e2db884c&quot;,
#                 {
#                     center: [41.92424828636364, -87.68122637045454],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfc8fec4a4e7c09e7583d5eeec32c5c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dfc8fec4a4e7c09e7583d5eeec32c5c5.addTo(map_7b75dc57570724e91fef5d27e2db884c);
#
#
#             var marker_c2a06ca682a94ca6d533dfdfd56cc922 = L.marker(
#                 [41.8955886, -87.6799623],
#                 {
# }
#             ).addTo(map_7b75dc57570724e91fef5d27e2db884c);
#
#
#         var popup_1ee7a40d0dc6c8883ff564a75eb9d94f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0b8600b589da1f9b84d0e20c587cb57 = $(`&lt;div id=&quot;html_c0b8600b589da1f9b84d0e20c587cb57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Old Oak Tap&lt;/div&gt;`)[0];
#                 popup_1ee7a40d0dc6c8883ff564a75eb9d94f.setContent(html_c0b8600b589da1f9b84d0e20c587cb57);
#
#
#
#         marker_c2a06ca682a94ca6d533dfdfd56cc922.bindPopup(popup_1ee7a40d0dc6c8883ff564a75eb9d94f)
#         ;
#
#
#
#
#             var marker_66ac65b2f635477282b3dbf59879d58f = L.marker(
#                 [41.8846392, -87.6475897],
#                 {
# }
#             ).addTo(map_7b75dc57570724e91fef5d27e2db884c);
#
#
#         var popup_c1a868c26bcdaed79045fcc8b59bf5b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45ce89d49620974a5a13f0e3dc836809 = $(`&lt;div id=&quot;html_45ce89d49620974a5a13f0e3dc836809&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Au Cheval&lt;/div&gt;`)[0];
#                 popup_c1a868c26bcdaed79045fcc8b59bf5b7.setContent(html_45ce89d49620974a5a13f0e3dc836809);
#
#
#
#         marker_66ac65b2f635477282b3dbf59879d58f.bindPopup(popup_c1a868c26bcdaed79045fcc8b59bf5b7)
#         ;
#
#
#
#
#             var marker_8d7689706c497bfa270575a1724e6a93 = L.marker(
#                 [41.8905226, -87.6307834],
#                 {
# }
#             ).addTo(map_7b75dc57570724e91fef5d27e2db884c);
#
#
#         var popup_12db7e843e9916ba14d193efb6851c31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9ab2fb2a9a79bcaec72ad7d9c53bde3 = $(`&lt;div id=&quot;html_c9ab2fb2a9a79bcaec72ad7d9c53bde3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Xoco&lt;/div&gt;`)[0];
#                 popup_12db7e843e9916ba14d193efb6851c31.setContent(html_c9ab2fb2a9a79bcaec72ad7d9c53bde3);
#
#
#
#         marker_8d7689706c497bfa270575a1724e6a93.bindPopup(popup_12db7e843e9916ba14d193efb6851c31)
#         ;
#
#
#
#
#             var marker_b886acd1f4b9eca7a5924a864970c64b = L.marker(
#                 [42.0583217, -87.6837479],
#                 {
# }
#             ).addTo(map_7b75dc57570724e91fef5d27e2db884c);
#
#
#         var popup_a2805c36976e84696d028248934a634f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3667959c9d1d10db9c64a4b8474b7b3 = $(`&lt;div id=&quot;html_e3667959c9d1d10db9c64a4b8474b7b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Al’s Deli&lt;/div&gt;`)[0];
#                 popup_a2805c36976e84696d028248934a634f.setContent(html_e3667959c9d1d10db9c64a4b8474b7b3);
#
#
#
#         marker_b886acd1f4b9eca7a5924a864970c64b.bindPopup(popup_a2805c36976e84696d028248934a634f)
#         ;
#
#
#
#
#             var marker_6dca0ece9cee435f19a887beecf3ead1 = L.marker(
#                 [41.8866036, -87.64853649999999],
#                 {
# }
#             ).addTo(map_7b75dc57570724e91fef5d27e2db884c);
#
#
#         var popup_1ba80605be08415a670c2573a97ca542 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_365bc204560781a4e77f146ee6adb122 = $(`&lt;div id=&quot;html_365bc204560781a4e77f146ee6adb122&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Publican Quality Meats&lt;/div&gt;`)[0];
#                 popup_1ba80605be08415a670c2573a97ca542.setContent(html_365bc204560781a4e77f146ee6adb122);
#
#
#
#         marker_6dca0ece9cee435f19a887beecf3ead1.bindPopup(popup_1ba80605be08415a670c2573a97ca542)
#         ;
#
#
#
#
#             var marker_7cb8ad45266d8aed528dccc2ebc3a3e1 = L.marker(
#                 [41.900114

# %%
print(data_result_df.head())
# Out:
#                    Menu                    Cafe  Price  \
# Rank
# 1                   BLT             Old Oak Tap    $10
# 2         Fried Bologna               Au Cheval     $9
# 3     Woodland Mushroom                    Xoco  $9.50
# 4            Roast Beef               Al’s Deli  $9.40
# 5                  PB&L  Publican Quality Meats    $10
#
#                        Address        Lat        Lng
# Rank
# 1        2109 W. Chicago Ave.,  41.895589 -87.679962
# 2         800 W. Randolph St.,  41.884639 -87.647590
# 3            445 N. Clark St.,  41.890523 -87.630783
# 4     914 Noyes St., Evanston,  42.058322 -87.683748
# 5          825 W. Fulton Mkt.,  41.886604 -87.648536
